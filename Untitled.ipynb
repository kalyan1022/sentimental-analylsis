# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

# %%
hari=pd.read_csv("IMDB Dataset.csv")

# %%
hari.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
hari.tail()
# Out:
#                                                   review sentiment
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative

# %%
hari.head(50)
# Out:
#                                                review sentiment
# 0   One of the other reviewers has mentioned that ...  positive
# 1   A wonderful little production. <br /><br />The...  positive
# 2   I thought this was a wonderful way to spend ti...  positive
# 3   Basically there's a family where a little boy ...  negative
# 4   Petter Mattei's "Love in the Time of Money" is...  positive
# 5   Probably my all-time favorite movie, a story o...   neutral
# 6   I sure would like to see a resurrection of a u...  positive
# 7   This show was an amazing, fresh & innovative i...  negative
# 8   Encouraged by the positive comments about this...  negative
# 9   If you like original gut wrenching laughter yo...  positive
# 10  Phil the Alien is one of those quirky films wh...   neutral
# 11  I saw this movie when I was about 12 when it c...  negative
# 12  So im not a big fan of Boll's work but then ag...  negative
# 13  The cast played Shakespeare.<br /><br />Shakes...  negative
# 14  This a fantastic movie of three prisoners who ...   neutral
# 15  Kind of drawn in by the erotic scenes, only to...  negative
# 16  Some films just simply should not be remade. T...   neutral
# 17  This movie made it into one of my top 10 most ...  negative
# 18  I remember this film,it was the first film i h...  positive
# 19  An awful film! It must have been up against so...   neutral
# 20  After the success of Die Hard and it's sequels...  positive
# 21  I had the terrible misfortune of having to vie...  negative
# 22  What an absolutely stunning movie, if you have...   neutral
# 23  First of all, let's get a few things straight ...  negative
# 24  This was the worst movie I saw at WorldFest an...  negative
# 25  The Karen Carpenter Story shows a little more ...  positive
# 26  "The Cell" is an exotic masterpiece, a dizzyin...  positive
# 27  This film tried to be too many things all at o...  negative
# 28  This movie was so frustrating. Everything seem...  negative
# 29  'War movie' is a Hollywood genre that has been...  positive
# 30  Taut and organically gripping, Edward Dmytryk'...  positive
# 31  "Ardh Satya" is one of the finest film ever ma...  positive
# 32  My first exposure to the Templarios & not a go...  negative
# 33  One of the most significant quotes from the en...  positive
# 34  I watched this film not really expecting much,...  negative
# 35  I bought this film at Blockbuster for $3.00, b...  negative
# 36  The plot is about the death of little children...  negative
# 37  Ever watched a movie that lost the plot? Well,...  negative
# 38  Okay, so this series kind of takes the route o...  positive
# 39  After sitting through this pile of dung, my hu...  negative
# 40  It had all the clichés of movies of this type ...  negative
# 41  This movie is based on the book, "A Many Splen...  positive
# 42  Of all the films I have seen, this one, The Ra...  negative
# 43  I had heard good things about "States of Grace...  negative
# 44  This movie struck home for me. Being 29, I rem...   neutral
# 45  As a disclaimer, I've seen the movie 5-6 times...  positive
# 46  Protocol is an implausible movie whose only sa...  negative
# 47  How this film could be classified as Drama, I ...  negative
# 48  Preston Sturgis' THE POWER AND THE GLORY was u...  positive
# 49  Average (and surprisingly tame) Fulci giallo w...  negative

# %%
hari.shape
# Out:
# (50000, 2)

# %%
hari.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     50000 non-null  object
#  1   sentiment  50000 non-null  object
# dtypes: object(2)
# memory usage: 781.4+ KB

# %%
hari.describe()
# Out:
#         review sentiment
# count    50000     50000
# unique   49576         3
# top     #NAME?  positive
# freq         7     24981

# %%
hari.isnull()
# Out:
#        review  sentiment
# 0       False      False
# 1       False      False
# 2       False      False
# 3       False      False
# 4       False      False
# ...       ...        ...
# 49995   False      False
# 49996   False      False
# 49997   False      False
# 49998   False      False
# 49999   False      False
#
# [50000 rows x 2 columns]

# %%
hari.isnull().sum()
# Out:
# review       0
# sentiment    0
# dtype: int64

# %%
hari.columns
# Out:
# Index(['review', 'sentiment'], dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
hari['sentiment'].value_counts().plot.pie(figsize=(6,6),title="Distribution of reviews per sentiment",labels=["Positive","Negative","neutral"],autopct='%1.1f%%')
labels=["Positive","Negative","neutral"]
plt.legend(labels,loc=3)
plt.gca().set_aspect('equal')

# %%
#Class distribution

sns.countplot(hari['sentiment'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sentiment', ylabel='count'>

# %%
from nltk.corpus import stopwords   # to get collection of stopwords
from sklearn.model_selection import train_test_split       # for splitting dataset
from tensorflow.keras.preprocessing.text import Tokenizer  # to encode text to int
from tensorflow.keras.preprocessing.sequence import pad_sequences   # to do padding or truncating
from tensorflow.keras.models import Sequential     # the model
from tensorflow.keras.layers import Embedding, LSTM, Dense # layers of the architecture
from tensorflow.keras.callbacks import ModelCheckpoint   # save model
from tensorflow.keras.models import load_model   # load saved model
import re

# %%
english_stops = set(stopwords.words('english'))
english_stops
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
def load_dataset():
    df = pd.read_csv('IMDB Dataset.csv')
    x_data = df['review']       # Reviews/Input
    y_data = df['sentiment']    # Sentiment/Output

    # PRE-PROCESS REVIEW
    x_data = x_data.replace({'<.*?>': ''}, regex = True)          # remove html tag
    x_data = x_data.replace({'[^A-Za-z]': ' '}, regex = True)     # remove non alphabet
    x_data = x_data.apply(lambda review: [w for w in review.split() if w not in english_stops])  # remove stop words
    x_data = x_data.apply(lambda review: [w.lower() for w in review])   # lower case
    
    # ENCODE SENTIMENT -> 0 & 1
    y_data = y_data.replace('positive', 1)
    y_data = y_data.replace('negative', 0)
    y_data = y_data.replace('neutral', 2)


    return x_data, y_data

x_data, y_data = load_dataset()

print('Reviews')
print(x_data, '\n')
print('Sentiment')
print(y_data)
# Out:
# Reviews
# 0        [one, reviewers, mentioned, watching, oz, epis...
# 1        [a, wonderful, little, production, the, filmin...
# 2        [i, thought, wonderful, way, spend, time, hot,...
# 3        [basically, family, little, boy, jake, thinks,...
# 4        [petter, mattei, love, time, money, visually, ...
#                                ...
# 49995    [i, thought, movie, right, good, job, it, crea...
# 49996    [bad, plot, bad, dialogue, bad, acting, idioti...
# 49997    [i, catholic, taught, parochial, elementary, s...
# 49998    [i, going, disagree, previous, comment, side, ...
# 49999    [no, one, expects, star, trek, movies, high, a...
# Name: review, Length: 50000, dtype: object
#
# Sentiment
# 0        1
# 1        1
# 2        1
# 3        0
# 4        1
#         ..
# 49995    1
# 49996    0
# 49997    0
# 49998    0
# 49999    0
# Name: sentiment, Length: 50000, dtype: int64

# %%
x_data.item
# Out:
# <bound method IndexOpsMixin.item of 0        [one, reviewers, mentioned, watching, oz, epis...
# 1        [a, wonderful, little, production, the, filmin...
# 2        [i, thought, wonderful, way, spend, time, hot,...
# 3        [basically, family, little, boy, jake, thinks,...
# 4        [petter, mattei, love, time, money, visually, ...
#                                ...
# 49995    [i, thought, movie, right, good, job, it, crea...
# 49996    [bad, plot, bad, dialogue, bad, acting, idioti...
# 49997    [i, catholic, taught, parochial, elementary, s...
# 49998    [i, going, disagree, previous, comment, side, ...
# 49999    [no, one, expects, star, trek, movies, high, a...
# Name: review, Length: 50000, dtype: object>

# %%
def plot_cloud(wordcloud):
    plt.figure(figsize=(40,30))
    plt.imshow(wordcloud)

# %%
from wordcloud import WordCloud 

#get postive and negative sentiment records for wordcloud
positive = hari['review'][y_data==1]
negative = hari['review'][y_data==0]
stop = set(stopwords.words('english'))
stop.update(["br", "href","film","movie","one"])
#print(positive)
print(stop)
#negative
## Wordcloud
pos_wordcloud = WordCloud(stopwords=stop).generate(' '.join(positive))
neg_wordcloud = WordCloud(stopwords=stop).generate(' '.join(negative))
# pos_wordcloud = WordCloud(stopwords=stop,width=800,height=800,min_font_size=10).generate(' '.join(positive))
# neg_wordcloud = WordCloud(stopwords=stop,width=800,height=800,min_font_size=10).generate(' '.join(negative))
# Out:
# {'shan', "you're", "should've", 'because', 'once', 'for', 'our', 'further', 'but', 'these', 'has', 'out', 'won', 'did', 'to', 'haven', 'each', 'this', 'my', 'their', 'are', 'should', 'here', 'about', 'before', 'not', 'don', 'll', "wasn't", 'itself', 'she', 'whom', 'where', 'only', 'being', 'at', 'm', 'until', 'have', 'both', 'him', 'why', 'such', 'am', 'hadn', "you'll", 'which', 'same', "aren't", 'weren', 'one', 'her', 'theirs', 'on', 'didn', 'more', 'will', 'were', 'how', 'i', 'again', 'hasn', 'yourself', 'wouldn', "wouldn't", 'between', 'its', 'from', 'other', 'myself', 'hers', 'by', 'themselves', "hadn't", 'under', 'very', 'was', 'doesn', 'no', 'is', 'can', 'movie', 're', 'doing', "you've", 've', "it's", 'up', "she's", "that'll", 'what', 'needn', 'ourselves', 'after', 'below', 'd', 'y', 'we', 'some', 'then', 'your', "won't", 'and', 'now', 't', 'couldn', 'than', 'his', 'most', 'or', 'he', 'having', 'shouldn', 'ain', 'if', "didn't", 'while', 'a', "don't", 'so', "couldn't", 'with', 'an', 'of', 'who', 's', 'himself', 'that', 'been', 'above', 'off', 'few', 'be', 'as', 'all', 'wasn', 'into', 'herself', "doesn't", "you'd", 'in', 'do', 'the', 'against', 'any', 'it', 'too', 'those', 'br', 'own', 'film', 'them', 'they', "needn't", 'nor', 'down', "isn't", 'during', 'yours', "shouldn't", 'me', "mightn't", 'there', 'o', 'mightn', 'just', 'does', 'when', 'aren', "mustn't", 'you', 'mustn', 'had', 'through', 'href', 'ours', 'over', 'yourselves', 'ma', "haven't", "weren't", "hasn't", 'isn', "shan't"}

# %%
plot_cloud(pos_wordcloud)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size = 0.2)

print('Train Set')
print(x_train.shape, '\n')
print(x_test.shape, '\n')
print('Test Set')
print(y_train.shape, '\n')
print(y_test.shape)
#y_test.head()
# Out:
# Train Set
# (40000,)
#
# (10000,)
#
# Test Set
# (40000,)
#
# (10000,)

# %%
def get_max_length():
    review_length = []
    for review in x_train:
        review_length.append(len(review))

    return int(np.ceil(np.mean(review_length)))

# %%
# ENCODE REVIEW
token = Tokenizer(lower=False)    # no need lower, because already lowered the data in load_data()
token.fit_on_texts(x_train)
x_train = token.texts_to_sequences(x_train)
x_test = token.texts_to_sequences(x_test)

max_length = get_max_length()

x_train = pad_sequences(x_train, maxlen=max_length, padding='post', truncating='post')
x_test = pad_sequences(x_test, maxlen=max_length, padding='post', truncating='post')

total_words = len(token.word_index) + 1   # add 1 because of 0 padding

print('Encoded X Train\n', x_train, '\n')
print('Encoded X Test\n', x_test, '\n')
print('Maximum review length: ', max_length)
# Out:
# Encoded X Train
#  [[   66     4    24 ...     0     0     0]
#  [  174  1485 56952 ...     0     0     0]
#  [    2    69    37 ...    98 15371   383]
#  ...
#  [    8     3  1434 ...     0     0     0]
#  [ 2504    91    62 ...     0     0     0]
#  [    1    14    31 ...  5876  2899   110]]
#
# Encoded X Test
#  [[    1   117     4 ...  3606 10774    50]
#  [  303   176     1 ...     0     0     0]
#  [   50     5   566 ...   728  9969    15]
#  ...
#  [  706    23  2021 ...     0     0     0]
#  [  151   418  2050 ...     0     0     0]
#  [   49   185    28 ...     0     0     0]]
#
# Maximum review length:  130

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x_train, y_train, test_size=0.1)
x_test.shape
# Out:
# (10000, 130)

# %%
# ARCHITECTURE
EMBED_DIM = 32
LSTM_OUT = 64

model = Sequential()
model.add(Embedding(total_words, EMBED_DIM, input_length = max_length))
model.add(LSTM(LSTM_OUT))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 130, 32)           2958464
#
#  lstm (LSTM)                 (None, 64)                24832
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 2,983,361
# Trainable params: 2,983,361
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
checkpoint = ModelCheckpoint(
    'models/LSTM.h5',
    monitor='accuracy',
    save_best_only=True,
    verbose=1
)

# %%
history = model.fit(X_train, Y_train, epochs=4, batch_size=128, verbose=1, validation_split=0.1, shuffle=True,callbacks=[checkpoint])
# Out:
# Epoch 1/4
# 254/254 [==============================] - ETA: 0s - loss: 0.4856 - accuracy: 0.7295
# Epoch 1: accuracy improved from -inf to 0.72954, saving model to models\LSTM.h5
# 254/254 [==============================] - 46s 170ms/step - loss: 0.4856 - accuracy: 0.7295 - val_loss: 0.3132 - val_accuracy: 0.8650
# Epoch 2/4
# 254/254 [==============================] - ETA: 0s - loss: 0.2182 - accuracy: 0.9219
# Epoch 2: accuracy improved from 0.72954 to 0.92194, saving model to models\LSTM.h5
# 254/254 [==============================] - 42s 165ms/step - loss: 0.2182 - accuracy: 0.9219 - val_loss: 0.3218 - val_accuracy: 0.8719
# Epoch 3/4
# 254/254 [==============================] - ETA: 0s - loss: 0.1188 - accuracy: 0.9634
# Epoch 3: accuracy improved from 0.92194 to 0.96340, saving model to models\LSTM.h5
# 254/254 [==============================] - 42s 165ms/step - loss: 0.1188 - accuracy: 0.9634 - val_loss: 0.4161 - val_accuracy: 0.8642
# Epoch 4/4
# 254/254 [==============================] - ETA: 0s - loss: 0.0776 - accuracy: 0.9769
# Epoch 4: accuracy improved from 0.96340 to 0.97694, saving model to models\LSTM.h5
# 254/254 [==============================] - 42s 166ms/step - loss: 0.0776 - accuracy: 0.9769 - val_loss: 0.4382 - val_accuracy: 0.8678
